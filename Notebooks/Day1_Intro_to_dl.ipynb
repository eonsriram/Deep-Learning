# %% [markdown]
# # Introduction to Deep Learning
#
#
# In this tutorial the following topics are covered:
#
# 1. What is learning?
# 2. What is deep learning?
# 3. Types of neural network
# 4. Artificial neural networks
# 5. A typical neural network
# 6. Elements of neural network
# 7. Why deep learning is popular these days
# 8. Applications of Deep Learning
# 9. Deep Learning Tools and Libraries

# %% [markdown]
# # What is learning?
#
#
# can you recognize these pictures? if yes , how?

# %%
from IPython.display import Image , display
display(Image('/content/drive/MyDrive/images/day1/1.jpg',width=300,height=300))
display(Image('/content/drive/MyDrive/images/day1/2.jpg',width=300,height=300))

# %% [markdown]
# image1 source- https://www.travelandleisure.com/attractions/landmarks-monuments/eiffel-tower-facts
#
# image2 source-https://www.thoughtco.com/chinese-flower-lotus-687523

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# The picture above is the picture of eiffel tower and the one below is of a lotus. Most of us would have recognised it but the question is how?
# The reason is that we all unknowingly try to capture certain properties or certain descriptors from any picture that we see and using those properties we have built a model which is embedded in our brain, so even if some of us who had never seen what eiffel tower or lotus looks like . we would have guessed that its either a tall tower or a flower.

# %% [markdown]
# #What is deep learning?
#
# ---

# %%
from IPython.display import Image 
Image('/content/drive/MyDrive/images/day1/3.png')

# %% [markdown]
# image source- https://towardsdatascience.com/cousins-of-artificial-intelligence-dda4edc27b55

# %% [markdown]
# **Deep Learning is a subset of Machine Learning, which on the other hand is a subset of Artificial Intelligence**. Artificial Intelligence refers to techniques that enable computers to behave like humans. Machine learning refers to the set of algorithms that are trained on data that can make this task possible i.e. the act of making decisions without explicitly being programmed.
#
# Deep Learning is just a type of Machine Learning, inspired by the structure of a human brain. Deep learning algorithms continuously work on the data provided to them and try to find patterns in them just as a human brain does before arriving at a conclusion. To achieve this, **deep learning uses a multi-layered structure of algorithms called neural networks.**

# %% [markdown]
# # Types of neural network
#
# * Feedforward Neural Networks (ANN)
#
# ---
# It is a group of multiple perceptrons or neurons at each layer. ANN is also known as a Feed-Forward Neural network because inputs are processed only in the forward direction.
# This type of neural networks are one of the simplest variants of neural networks. They pass information in one direction, through various input nodes, until it makes it to the output node. The network may or may not have hidden node layers, making their functioning more interpretable.
#
#
# * Recurrent Neural Networks (RNN)
#
# ---
# are more complex. They save the output of processing nodes and feed the result back into the model (they did not pass the information in one direction only). This is how the model is said to learn to predict the outcome of a layer. Each node in the RNN model acts as a memory cell, continuing the computation and implementation of operations. If the network’s prediction is incorrect, then the system self-learns and continues working towards the correct prediction during backpropagation.
#
#
#
# * Convolution Neural Networks (CNN)
#
# ---
#  They are one of the most popular models used today. This neural network computational model uses a variation of multilayer perceptrons and contains one or more convolutional layers that can be either entirely connected or pooled. These convolutional layers create feature maps that record a region of image which is ultimately broken into rectangles and sent out for nonlinear processing.
#
#
#
# Don't worry if you are not able to understand these concepts or terms,all types of neural network will be discussed in detail as we further proceed.

# %% [markdown]
# # Artificial neural networks
#
# ---
#
# Neural networks are parallel computing devices, which is based on the computer model of the human brain. The human brain can process large amount of information within just a few milliseconds that might take several hours or sometimes even days for a traditional digital computer depending on the processing power.The ANN is an efficient computing system whose central theme is borrowed from the analogy of biological neural networks. ANN acquires a large collection of units that are interconnected in some pattern to allow communication between the units. These units, also referred to as nodes or neurons which operate in parallel.
#
# Every neuron is connected with another neuron through a link.
#
# Here are some biological analogies from which the concept of neural network came into picture

# %%
from IPython.display import Image 
Image('/content/drive/MyDrive/images/day1/4.jpg')

# %% [markdown]
# image source- https://www.tutorialspoint.com/artificial_neural_network/artificial_neural_network_basic_concepts.htm

# %% [markdown]
# A typical neuron consists of the following four parts-
#
# Dendrites − They are responsible for receiving the information from other neurons it is connected to.
#
# cell body − It is responsible for processing of information which they have received from dendrites.
#
# Axon − It is the medium through which neurons sends the information.
#
# Synapses − It is the connection between the axon and other neuron dendrites.

# %%
from IPython.display import Image 
Image('/content/drive/MyDrive/images/day1/5.png')

# %% [markdown]
# image source- https://medium.com/analytics-vidhya/introduction-to-artificial-neural-networks-ann-3109578d61ab

# %% [markdown]
# # Structure of a typical Neural Network
#
# ---

# %%
from IPython.display import Image 
Image('/content/drive/MyDrive/images/day1/6.jpg')

# %% [markdown]
# image source- https://www.tutorialspoint.com/artificial_intelligence/artificial_intelligence_neural_networks.htm

# %% [markdown]
# Whenever we see any object or an image we try to compare this new information with the things about which we already know and arrive or come to a conclusion. If the object we see is something new then based on the the information we already have or learnt through out our entire life we try to come to the closest possible conclusion as discussed above.This is how deep learning algorithm works.

# %% [markdown]
# # Elements of a neural network
#
# ---
#
#
#
#
#
#
# ##Input Layer :
#   This layer accepts input features. It provides information from the outside world to the network, no computation is performed at this layer, nodes here just pass on the information(features) to the hidden layer.
#
# ## Hidden layer :
#   Nodes of this layer are not exposed to the outer world, they are the part of the abstraction provided by any neural network. Hidden layer performs all sort of computation on the features entered through the input layer and transfer the result to the output layer.
#
# ## Output layer :
#   This layer bring up the information learned by the network to the outer world.

# %%
from IPython.display import Image
Image('/content/drive/MyDrive/deep_learning/pics/day1/7.png')

# %% [markdown]
# image source- https://www.geeksforgeeks.org/activation-functions-neural-networks/

# %% [markdown]
#  * i1 ,i2 refers to the inputs
#
#  * w1 ,w2 ,w3 ,w4 ,w5 w6 are the weights
#
#  * h1 and h2 are the hidden layers
#
#  * out refers to the output predicted by our model.
#
# The above points and thier roles will be discussed in detail as we further proceed.

# %% [markdown]
# # How is Machine Learning different from Deep Learning?
#
# ---
#
#
#
# **Deep learning does not need feature extraction.**
#
# algorithms used in machine learning are algorithms that cannot normally be applied directly to the raw data. We need a preprocessing step called Feature Extraction.
# The result of Feature Extraction is a representation of the given raw data that can now be used by machine learning algorithms to perform a task.
#
# On the other side are the artificial neural networks of Deep Learning which do not need Feature Extraction.
# The layers are able to learn directly and on their own.

# %%
from IPython.display import Image
Image('/content/drive/MyDrive/images/day1/8.png')

# %% [markdown]
# image source-https://lawtomated.com/a-i-technical-machine-vs-deep-learning/

# %% [markdown]
# *The feature extraction step is already part of the process that takes place in an artificial neural network.*
#
#
# For example, if you want to use a machine learning model to determine if a particular image is showing a car or not, we humans first need to identify the features of a car (shape, size, windows, wheels, etc.) extract the feature and give them to the algorithm as input data.
#
# So, in machine learning, a programmer must intervene directly in the action for the model to come to a conclusion.
#
# In deep learning,the model would recognize these unique characteristics by itself and make correct predictions

# %% [markdown]
# Watch [this](https://www.youtube.com/watch?v=Tf9koajUwmo) video(optional) by IIT Bombay for a quick refresher on Deep Learning.

# %% [markdown]
# # Applications of deep learning
#
#  *Some of the applications of deep learning are listed below-*
#
# 1. **Self-driving cars**
#
#   Deep neural networks are used to detect roads, cars, objects, and people in video feeds from cameras installed around the vehicle.You can think of it how a child learns through constant experiences and replication.
#
#
# 2. **Healthcare**
#
#  Deep learning models can be trained to look at images, identify abnormalities, and point to areas that need attention, thus improving the accuracy of all these processes.With their multiple levels of representation and results that surpass human accuracy, deep learning has particularly found widespread applications in health informatics and biomedicine
#
#
# 3. **Voice Search & Voice-Activated Assistants**
#
#   One of the most popular usage areas of deep learning is voice search & voice-activated intelligent assistants.They learn to understand your commands by evaluating natural human language to execute them. Another capability virtual assistants are endowed with is to translate your speech to text, make notes for you, and book appointments
#
# 4. **Automatically Adding Sounds To Silent Movies**
#
#   The system is trained using various examples of video with sound and creating different sounds. A deep learning model associates the video frames with a database of pre-rerecorded sounds in order to select a sound to play that best matches with what is happening in the scene.
#
# 5. **Automatic Translation of Text and images**
#
#   This is a task where given words, phrase or sentence in one language, automatically translate it into another language. Google assistant, Siri, Cortana, and Alexa are using speech recognition technology to follow the voice instructions.
#
#
# 6. **Image Recognition and classification**
#
#   Another popular area regarding deep learning is image recognition. It aims to recognize and identify people and objects in images as well as to understand the content and context.
# This task requires the classification of objects within a photograph as one of a set of previously known objects.One of the most popular applications is Automatic friend tagging suggestion
#
#
# 7. **Fraud news detection**
#
#   Deep Learning helps develop classifiers that can detect fake or biased news and remove it from your feed and warn you of possible privacy breaches.. The Cambridge Analytica is a classic example of how fake news, personal information, and statistics can influence reader perception
#
#
# 8. **Advertising**
#
#   Advertising is another key area that has been transformed by deep learning. It has been used by both publishers and advertisers to increase the relevancy of their ads and boost the return on investment of their advertising campaigns.

# %% [markdown]
# # Tools and libraries
#
# This will provide an overview of some of the most effective and widely used libraries and languages for deep learning (DL) solutions engineering and deployment.
#
# 1. Python
#
#   Python is a general-purpose language and can be successfully applied to various DL tasks.
# The language itself is very simple and therefore easy to learn. Furthermore, you don’t have to know Python from inside out to be able to experiment with ML and create ML algorithms
#
#     https://www.python.org/downloads/
#
#
# 2. Jupyter Notebook
#
#   In traditional software development, you spend most of your programming time in text editors or IDE, while in Data Science, most of the code is written in Jupyter Notebook.
#   This is a simple and powerful data analysis tool that allows you to write code in Python, R and other languages, add text descriptions to Markdown, as well as embed graphs and charts directly into an interactive web page.
#
#     https://jupyter.org/install
#
#
# 3. scikit learn
#
#   Scikit-learn is one of the most popular DL libraries today. It supports most of DL algorithms.In addition, Scikit-learn contains many useful tools for preparing data and analyzing results.
#
#     The following link has some basic scikit learn tutorials- https://scikit-learn.org/stable/tutorial/basic/tutorial.html
#
#     https://scikit-learn.org/stable/tutorial/index.html
#
#
# 4. Pandas
#
#   Data analysis and preparation often takes most of the time when solving DL problems. The data can be obtained in CSV, JSON, Excel or other structured (or not so) format, and you need to process them in order to use them in DL models.
#   For these purposes, the Pandas library is used. It is a powerful tool that allows you to quickly analyze, modify and prepare data for future use in other ML and DL libraries, such as Scikit-learn, TensorFlow or PyTorch.
#
#   The following link has some basic pandas tutorials- https://www.datacamp.com/community/blog/python-pandas-cheat-sheet?utm_source=adwords_ppc&utm_campaignid=1455363063&utm_adgroupid=65083631748&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=332602034358&utm_targetid=aud-392016246653:dsa-473406587915&utm_loc_interest_ms=&utm_loc_physical_ms=9301773&gclid=Cj0KCQiAvP6ABhCjARIsAH37rbQmP56IJcaCatKEJcSZhfArf9Fwrwa8sKTqTEHWsyhtFiqsH0uD4T8aAiwkEALw_wcB
#
#
#
# 5. NumPy
#
#   The main functionality of NumPy is to support multidimensional data arrays and fast linear algebra algorithms. That is why NumPy is a key component of Scikit-learn, SciPy, and Pandas.
#
#   The following link has some basic numpy commands- https://www.dataquest.io/blog/numpy-cheat-sheet/
#
#
# 6. Matplotlib and Seaborn
#
#   It allows you to create a variety of graphs and charts to visualize the results of data analytics. Graphics created in Matplotlib can be easily integrated into Jupyter Notebook. This makes it possible to visualize the data and the results obtained during the processing of models.
#
#   Many additional packages have been created for this library. One of the most popular ones is Seaborn. Its main feature is a ready-made set of the most frequently used statistical charts and graphs..
#
#   The following link has some basic matplotlib and seaborn tutorials
#
#     matplotlib-https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf
#
#     seaborn- https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Seaborn_Cheat_Sheet.pdf
#
#
#
# 7. Tensorflow
#
#   TensorFlow is an open-source library developed by Google primarily for deep learning applications. It also supports traditional machine learning.
#
#     basic Tensorflow tutorials- https://www.tensorflow.org/tutorials
#
# 8. Keras
#
#   Keras is a powerful and easy-to-use free open source Python library for developing and evaluating deep learning models.Keras is an add-on to Tensorflow.
#
#  basic Keras tutorials -https://www.tensorflow.org/tutorials/keras/classification
#
#
# 9. PyTorch
#
#   PyTorch is the second most popular DL library after Tensorflow. Created by Facebook and designed specifically for Python, it uses standard idioms.
#   PyTorch is also easier to debug because the code is executed as a regular Python code – there is no compilation step, as in TensorFlow. Therefore, you can easily use the Python debugger here.
#
#     basic pytorch tutorials-https://pytorch.org/tutorials/beginner/ptcheat.html
