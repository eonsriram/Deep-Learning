# %% [markdown]
# # **Introduction to Convolutional Neural Networks (CNNs)**
#
# A Convolutional Neural Network (ConvNet/CNN) is a deep learning algorithm which is used for image classification, image and video recognition and many other applications.
#
# In this tutorial we will explain the features, applications and architecture of CNN.

# %% [markdown]
# ## **Features of CNN**

# %% [markdown]
# The architecture of Convolutional networks was inspired by the way neurons are organized in visual cortex in human brain (the part of brain that is responsible for vision). The CNNs takes image as an input, learns the features from the image and differentiates one image from another.
#
# We will also see that the pre-processing required in a ConvNet is low as compared to other classification algorithms as the ConvNet have the ability to learn the characteristics.

# %% [markdown]
# ## **Applications of CNNs**

# %% [markdown]
# Convolutional Neural Networks (CNNs) have a wide range of applications. A few of them are described below.

# %% [markdown]
# #### **1. Image recognition**

# %% [markdown]
# CNNs are often used in image recognition systems.
# Image recognition is the process of taking an input (like a picture) and outputting the probability that the input belongs to a class (for example, given an nput image of a person, the Convet can give an ouput - there’s a 90% probability that this input is a person).

# %% [markdown]
# Go through the link [here](https://medium.com/nybles/create-your-first-image-recognition-classifier-using-cnn-keras-and-tensorflow-backend-6eaab98d14dd) in brief to understand how image recognition systems are built.

# %% [markdown]
# ### **2. Video analysis**

# %% [markdown]
# Video Analysis is the process of analyzing patterns in the data present in video streams by considering that the videos are nothing but a sequence of images. Videos are more complex than images since they have another (temporal) dimension of time.

# %% [markdown]
# One such advanced video based CNN analysis is shown in the link  https://cv.gluon.ai/contents.html

# %% [markdown]
# ### **3. Facial Recognition**

# %% [markdown]
# Facial Recognition is one of the most dominant application of CNNs as they are more versatile in extracting the features of human faces.
#
# Facial recognition is a complex process. Some steps used in facial recognition include:
# 1. Identifying multiple faces in a picture.
# 1. Focusing on the faces despite external factors, such as brightness, angle, pose.
# 1. Identifying unique features from the face.
# 1. Comparing with already existing data in the database to match a face with a name.

# %% [markdown]
# ![1-3.png](data:image/png;base64,...)

# %% [markdown]
# The image shows how the facial landmarks and facial features are detected to identify the person

# %% [markdown]
# ### **4. Analyzing Documents**

# %% [markdown]
# Convolutional Neural Networks (CNNs) can also be used for *document analysis.* This is not just useful for handwriting analysis, but is also used in recognizer softwares. It has various uses like scanning a document to convert the image data to text data and many more!
#
# Here is an example of Real-Time Translation of Languages by [Google Lens](https://lens.google.com/)
#
# ![](https://lh3.googleusercontent.com/5yWcvs2vmyGudMU-zwHEQ6BjTpy1qAt1PoLAFZcHop3Gzv-eXXb9TwG6KeNzCG4JES9cvgAul4USGQqVW95ZOUKxQlDHd8i6oes6sA=w0)

# %% [markdown]
# ### **5. Climate Change**

# %% [markdown]
# CNNs play a major role in estimating climate change, especially in understanding the reasons why we see such drastic changes and how we could experiment in decaying the effect. Satellite Imagery is a major contributor to the collection of Climate Data.

# %% [markdown]
# ## **Architecture of CNN**

# %% [markdown]
# Now that you know some of the applications of CNN. Let us take a look at the architecture of CNN.
#
# A convolutional neural network consists of an input layer, hidden layers and an output layer. The hidden layers of a CNN typically consist of *convolutional layers, pooling layers, fully connected layers*. In a convolutional neural network, the hidden layers include layers that perform ***convolutions***, which we'll discuss in upcoming topics.

# %% [markdown]
# The input image can be an RGB image which is separated by its three colur planes - Red, Blue and Green. The input image could also be of other types such as Grayscale or HSV or higher domensions in which case it will be computationally intensive. Here is where CNNs play a major role, the ConvNet reduces the images to a form which is easier to process and also gives good prediction. In simple terms, ConvNet is able to capture the spatial and temporal dependencies in an input image by using filers.

# %% [markdown]
# The below image shows a typical structure of CNN - an input, an output layer, as well as multiple hidden layers. The image also shows hidden layers of a CNN typically consist of *convolutional layers, pooling layers, fully connected layers*. Let us now understand what these layers are.

# %% [markdown]
# ![1-6.png](data:image/png;base64,...)

# %% [markdown]
# #### **Convolutional Layer**
#
# >Convolutional Layers are the layers that are most significant in CNN models, and hence it's name- Convolutional Neural Networks. These layers perform actions that results in the output having different features, which are more simpler to train the model.
#
# Convolutional Layers have a moving filter(matrix) also called as the weight matrix or Kernel. The filter slides over the input image (convolution operation) to produce a feature map.
# Weight matrix/Kernel and Input Image multiply (dot product) and summed to produce the feature map.

# %% [markdown]
# #### **Pooling layer**
#
# >Pooling layers are used to progressively reduce the spatial size of the input. The main objective is to reduce the dimensions of input matrix and thus, to reduce the training complexity.
#
# We move a window across a 2D input space, where a certain characteristic like Maximum or Average from that space within that window is the output.
# It is also called as downsampling layer because it reduces the number of parameters within the model.

# %% [markdown]
# #### **Fully Connected Layer**
#
# >Fully Connected Layers are similar to that of hidden layers in regular neural networks.
#
# In Fully Connected layer all neurons are connected to all neurons of the previous layer. After feature extraction we need to classify the data into various classes, this can be done using a fully connected neural network.
# This works similar to that of a Regular Feed forward Neural Network.
# The layer has to flatten and is connected to the output layer, that’s what fully connected does, it flattens. It is also called the dense layer.
